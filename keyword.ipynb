# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
keyword_list = pd.read_excel("www_abcabinet_us_-_keyword_strategy.xlsx")
keyword_list.head()
# Out:
#                          url  \
# 0  https://www.abcabinet.us/
# 1  https://www.abcabinet.us/
# 2  https://www.abcabinet.us/
# 3  https://www.abcabinet.us/
# 4  https://www.abcabinet.us/
#
#                                                title  \
# 0  San Jose Custom Cabinets | American Built Cabi...
# 1  San Jose Custom Cabinets | American Built Cabi...
# 2  San Jose Custom Cabinets | American Built Cabi...
# 3  San Jose Custom Cabinets | American Built Cabi...
# 4  San Jose Custom Cabinets | American Built Cabi...
#
#                                          description  \
# 0  american built cabinets designs, manufactures,...
# 1  american built cabinets designs, manufactures,...
# 2  american built cabinets designs, manufactures,...
# 3  american built cabinets designs, manufactures,...
# 4  american built cabinets designs, manufactures,...
#
#                             keyword keyword type  volume  keyword difficulty  \
# ...
